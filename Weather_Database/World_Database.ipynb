# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Import the time module.
import time

# Import the API key.
from config import g_key

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=657be9661dd6511a9e2c7728f26ea5d2

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-pierre
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | yar-sale
# Processing Record 4 of Set 1 | port-cartier
# Processing Record 5 of Set 1 | taoudenni
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | codrington
# Processing Record 12 of Set 1 | yeppoon
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | turukhansk
# Processing Record 15 of Set 1 | kontagora
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | catalao
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | tonantins
# Processing Record 22 of Set 1 | tautira
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | margate
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | grindavik
# Processing Record 29 of Set 1 | bilibino
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | santa fe
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | santa cruz
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | apolda
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | faya
# Processing Record 42 of Set 1 | bandarbeyla
# Processing Record 43 of Set 1 | kodinsk
# Processing Record 44 of Set 1 | bathsheba
# Processing Record 45 of Set 1 | comodoro rivadavia
# Processing Record 46 of Set 1 | henties bay
# Processing Record 47 of Set 1 | severnyy
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 2 | pacific grove
# Processing Record 2 of Set 2 | karmana
# City not found. Skipping...
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | hamilton
# Processing Record 5 of Set 2 | fukue
# Processing Record 6 of Set 2 | bud
# Processing Record 7 of Set 2 | evora
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | birao
# Processing Record 10 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 2 | boke
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | kismayo
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | pierre
# Processing Record 16 of Set 2 | kaitangata
# Processing Record 17 of Set 2 | bam
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | severo-kurilsk
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | atuona
# Processing Record 24 of Set 2 | oktyabrskiy
# Processing Record 25 of Set 2 | kavaratti
# Processing Record 26 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 2 | komsomolskiy
# Processing Record 30 of Set 2 | grand gaube
# Processing Record 31 of Set 2 | talcher
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | beloha
# Processing Record 34 of Set 2 | baruun-urt
# Processing Record 35 of Set 2 | kloulklubed
# Processing Record 36 of Set 2 | pitsunda
# Processing Record 37 of Set 2 | mikhaylovka
# Processing Record 38 of Set 2 | trofors
# Processing Record 39 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | katsuura
# Processing Record 42 of Set 2 | constitucion
# Processing Record 43 of Set 2 | balkanabat
# Processing Record 44 of Set 2 | kirakira
# Processing Record 45 of Set 2 | deputatskiy
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | corinto
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | lamar
# Processing Record 1 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 3 | parrita
# Processing Record 3 of Set 3 | isangel
# Processing Record 4 of Set 3 | conceicao da barra
# Processing Record 5 of Set 3 | ponta do sol
# Processing Record 6 of Set 3 | parczew
# Processing Record 7 of Set 3 | guerrero negro
# Processing Record 8 of Set 3 | talnakh
# Processing Record 9 of Set 3 | kodar
# Processing Record 10 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 3 | kalmunai
# Processing Record 12 of Set 3 | tanggu
# Processing Record 13 of Set 3 | severodvinsk
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | oriximina
# Processing Record 17 of Set 3 | bismarck
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | college
# Processing Record 20 of Set 3 | erhlin
# City not found. Skipping...
# Processing Record 21 of Set 3 | bagnan
# Processing Record 22 of Set 3 | namatanai
# Processing Record 23 of Set 3 | nanortalik
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | lorengau
# Processing Record 26 of Set 3 | umkomaas
# Processing Record 27 of Set 3 | pitmedden
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | wahiawa
# Processing Record 31 of Set 3 | nushki
# Processing Record 32 of Set 3 | rafaela
# Processing Record 33 of Set 3 | prieska
# Processing Record 34 of Set 3 | canavieiras
# Processing Record 35 of Set 3 | wanning
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | olafsvik
# Processing Record 38 of Set 3 | port macquarie
# Processing Record 39 of Set 3 | manaure
# Processing Record 40 of Set 3 | east london
# Processing Record 41 of Set 3 | sorland
# Processing Record 42 of Set 3 | muncar
# Processing Record 43 of Set 3 | ambilobe
# Processing Record 44 of Set 3 | portland
# Processing Record 45 of Set 3 | ostrovnoy
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | srandakan
# Processing Record 48 of Set 3 | havelock
# Processing Record 49 of Set 3 | neftcala
# Processing Record 50 of Set 3 | kawalu
# Processing Record 1 of Set 4 | fairbanks
# Processing Record 2 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 4 | lavrentiya
# Processing Record 4 of Set 4 | hit
# Processing Record 5 of Set 4 | george
# Processing Record 6 of Set 4 | cape town
# Processing Record 7 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 4 | yakeshi
# Processing Record 9 of Set 4 | bluff
# Processing Record 10 of Set 4 | kidal
# Processing Record 11 of Set 4 | kavieng
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | juba
# Processing Record 14 of Set 4 | tambovka
# Processing Record 15 of Set 4 | vila franca do campo
# Processing Record 16 of Set 4 | kisangani
# Processing Record 17 of Set 4 | embu-guacu
# Processing Record 18 of Set 4 | terra boa
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | teguise
# Processing Record 21 of Set 4 | torbay
# Processing Record 22 of Set 4 | mehamn
# Processing Record 23 of Set 4 | pisco
# Processing Record 24 of Set 4 | tigil
# Processing Record 25 of Set 4 | hofn
# Processing Record 26 of Set 4 | wentzville
# Processing Record 27 of Set 4 | flinders
# Processing Record 28 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 4 | baoning
# Processing Record 30 of Set 4 | port hardy
# Processing Record 31 of Set 4 | flin flon
# Processing Record 32 of Set 4 | sulina
# Processing Record 33 of Set 4 | calamba
# Processing Record 34 of Set 4 | kehtna
# Processing Record 35 of Set 4 | begusarai
# Processing Record 36 of Set 4 | kapit
# Processing Record 37 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 4 | urumqi
# Processing Record 39 of Set 4 | kurilsk
# Processing Record 40 of Set 4 | yabrud
# Processing Record 41 of Set 4 | nagato
# Processing Record 42 of Set 4 | mitsamiouli
# Processing Record 43 of Set 4 | teterow
# Processing Record 44 of Set 4 | sale
# Processing Record 45 of Set 4 | ust-kuyga
# Processing Record 46 of Set 4 | fengcheng
# Processing Record 47 of Set 4 | hami
# Processing Record 48 of Set 4 | wamba
# Processing Record 49 of Set 4 | quatre cocos
# Processing Record 50 of Set 4 | zabol
# Processing Record 1 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 5 | byron bay
# Processing Record 3 of Set 5 | guia de isora
# Processing Record 4 of Set 5 | la ronge
# Processing Record 5 of Set 5 | deer lake
# Processing Record 6 of Set 5 | kambove
# Processing Record 7 of Set 5 | butaritari
# Processing Record 8 of Set 5 | huarmey
# Processing Record 9 of Set 5 | tura
# Processing Record 10 of Set 5 | kishapu
# Processing Record 11 of Set 5 | acopiara
# Processing Record 12 of Set 5 | sinnai
# Processing Record 13 of Set 5 | castelnaudary
# Processing Record 14 of Set 5 | atlantic beach
# Processing Record 15 of Set 5 | kimbe
# Processing Record 16 of Set 5 | camacha
# Processing Record 17 of Set 5 | iralaya
# Processing Record 18 of Set 5 | muisne
# Processing Record 19 of Set 5 | namyslow
# Processing Record 20 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 21 of Set 5 | hovd
# Processing Record 22 of Set 5 | eureka
# Processing Record 23 of Set 5 | svetlogorsk
# Processing Record 24 of Set 5 | san cristobal
# Processing Record 25 of Set 5 | dingli
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 5 | kentau
# Processing Record 29 of Set 5 | nouadhibou
# Processing Record 30 of Set 5 | ocean city
# Processing Record 31 of Set 5 | waihi beach
# Processing Record 32 of Set 5 | solnechnyy
# Processing Record 33 of Set 5 | sabang
# Processing Record 34 of Set 5 | isla mujeres
# Processing Record 35 of Set 5 | nalut
# Processing Record 36 of Set 5 | rognedino
# Processing Record 37 of Set 5 | vung tau
# Processing Record 38 of Set 5 | xuddur
# Processing Record 39 of Set 5 | vardo
# Processing Record 40 of Set 5 | coalcoman
# City not found. Skipping...
# Processing Record 41 of Set 5 | tuktoyaktuk
# Processing Record 42 of Set 5 | provideniya
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 5 | asyut
# Processing Record 46 of Set 5 | port hedland
# Processing Record 47 of Set 5 | bol
# Processing Record 48 of Set 5 | pacifica
# Processing Record 49 of Set 5 | manadhoo
# Processing Record 50 of Set 5 | sinnamary
# Processing Record 1 of Set 6 | vao
# Processing Record 2 of Set 6 | avera
# Processing Record 3 of Set 6 | andenes
# Processing Record 4 of Set 6 | lundazi
# Processing Record 5 of Set 6 | genhe
# Processing Record 6 of Set 6 | saldanha
# Processing Record 7 of Set 6 | vanimo
# Processing Record 8 of Set 6 | tabas
# Processing Record 9 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 6 | chuy
# Processing Record 11 of Set 6 | chiredzi
# Processing Record 12 of Set 6 | a
# City not found. Skipping...
# Processing Record 13 of Set 6 | aksu
# Processing Record 14 of Set 6 | kabanjahe
# Processing Record 15 of Set 6 | lukoyanov
# Processing Record 16 of Set 6 | fuerte olimpo
# Processing Record 17 of Set 6 | kachikau
# City not found. Skipping...
# Processing Record 18 of Set 6 | nioki
# Processing Record 19 of Set 6 | masaka
# Processing Record 20 of Set 6 | ayan
# Processing Record 21 of Set 6 | esperance
# Processing Record 22 of Set 6 | tasiilaq
# Processing Record 23 of Set 6 | talawdi
# City not found. Skipping...
# Processing Record 24 of Set 6 | finnsnes
# Processing Record 25 of Set 6 | tual
# Processing Record 26 of Set 6 | luganville
# Processing Record 27 of Set 6 | los llanos de aridane
# Processing Record 28 of Set 6 | vrangel
# Processing Record 29 of Set 6 | parabel
# Processing Record 30 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 31 of Set 6 | santa cruz cabralia
# Processing Record 32 of Set 6 | airai
# Processing Record 33 of Set 6 | khatanga
# Processing Record 34 of Set 6 | uray
# Processing Record 35 of Set 6 | yatou
# Processing Record 36 of Set 6 | tuatapere
# Processing Record 37 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 6 | sussex
# Processing Record 39 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 40 of Set 6 | cockburn town
# Processing Record 41 of Set 6 | bethel
# Processing Record 42 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 6 | port blair
# Processing Record 44 of Set 6 | saint-georges
# Processing Record 45 of Set 6 | loubomo
# Processing Record 46 of Set 6 | bodo
# Processing Record 47 of Set 6 | santa isabel do rio negro
# Processing Record 48 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 6 | ugoofaaru
# Processing Record 50 of Set 6 | castro
# Processing Record 1 of Set 7 | timaru
# Processing Record 2 of Set 7 | livingston
# Processing Record 3 of Set 7 | moen
# Processing Record 4 of Set 7 | olinda
# Processing Record 5 of Set 7 | killybegs
# Processing Record 6 of Set 7 | nouakchott
# Processing Record 7 of Set 7 | nemuro
# Processing Record 8 of Set 7 | sturgeon bay
# Processing Record 9 of Set 7 | port jervis
# Processing Record 10 of Set 7 | corn island
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | salalah
# Processing Record 13 of Set 7 | carbonia
# Processing Record 14 of Set 7 | sambava
# Processing Record 15 of Set 7 | sobolevo
# Processing Record 16 of Set 7 | seredka
# Processing Record 17 of Set 7 | odienne
# Processing Record 18 of Set 7 | chokurdakh
# Processing Record 19 of Set 7 | anadyr
# Processing Record 20 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 7 | tahe
# Processing Record 22 of Set 7 | uruacu
# Processing Record 23 of Set 7 | laguna
# Processing Record 24 of Set 7 | inhambane
# Processing Record 25 of Set 7 | taizhou
# Processing Record 26 of Set 7 | saint george
# Processing Record 27 of Set 7 | smithers
# Processing Record 28 of Set 7 | plaster rock
# Processing Record 29 of Set 7 | soligalich
# Processing Record 30 of Set 7 | sulangan
# Processing Record 31 of Set 7 | lagos
# Processing Record 32 of Set 7 | karasjok
# Processing Record 33 of Set 7 | sola
# Processing Record 34 of Set 7 | ous
# Processing Record 35 of Set 7 | ust-maya
# Processing Record 36 of Set 7 | carnarvon
# Processing Record 37 of Set 7 | juneau
# Processing Record 38 of Set 7 | northam
# Processing Record 39 of Set 7 | coihaique
# Processing Record 40 of Set 7 | addis zemen
# City not found. Skipping...
# Processing Record 41 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 7 | ambikapur
# Processing Record 43 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 7 | xai-xai
# Processing Record 45 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 46 of Set 7 | normal
# Processing Record 47 of Set 7 | haines junction
# Processing Record 48 of Set 7 | larap
# Processing Record 49 of Set 7 | misratah
# Processing Record 50 of Set 7 | menongue
# Processing Record 1 of Set 8 | lata
# Processing Record 2 of Set 8 | san vicente
# Processing Record 3 of Set 8 | khash
# Processing Record 4 of Set 8 | grand-lahou
# Processing Record 5 of Set 8 | koslan
# Processing Record 6 of Set 8 | vestmannaeyjar
# Processing Record 7 of Set 8 | changping
# Processing Record 8 of Set 8 | filingue
# Processing Record 9 of Set 8 | quelimane
# Processing Record 10 of Set 8 | yulara
# Processing Record 11 of Set 8 | mareeba
# Processing Record 12 of Set 8 | torbat-e jam
# Processing Record 13 of Set 8 | murray bridge
# Processing Record 14 of Set 8 | shubarshi
# Processing Record 15 of Set 8 | antofagasta
# Processing Record 16 of Set 8 | vostok
# Processing Record 17 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 18 of Set 8 | bontang
# Processing Record 19 of Set 8 | verkhoyansk
# Processing Record 20 of Set 8 | almeirim
# Processing Record 21 of Set 8 | sao goncalo do amarante
# Processing Record 22 of Set 8 | malazgirt
# Processing Record 23 of Set 8 | belmonte
# Processing Record 24 of Set 8 | lichinga
# Processing Record 25 of Set 8 | cabo san lucas
# Processing Record 26 of Set 8 | lasa
# Processing Record 27 of Set 8 | dzaoudzi
# Processing Record 28 of Set 8 | lewisville
# Processing Record 29 of Set 8 | san patricio
# Processing Record 30 of Set 8 | lucapa
# Processing Record 31 of Set 8 | kralendijk
# Processing Record 32 of Set 8 | boyolangu
# Processing Record 33 of Set 8 | sangar
# Processing Record 34 of Set 8 | valdivia
# Processing Record 35 of Set 8 | lapy
# Processing Record 36 of Set 8 | baijiantan
# Processing Record 37 of Set 8 | mineral wells
# Processing Record 38 of Set 8 | lakatoro
# Processing Record 39 of Set 8 | touros
# Processing Record 40 of Set 8 | bassano
# Processing Record 41 of Set 8 | jhanjharpur
# Processing Record 42 of Set 8 | aklavik
# Processing Record 43 of Set 8 | metabetchouan
# City not found. Skipping...
# Processing Record 44 of Set 8 | chik
# Processing Record 45 of Set 8 | ilulissat
# Processing Record 46 of Set 8 | nautla
# Processing Record 47 of Set 8 | smoky lake
# Processing Record 48 of Set 8 | nogliki
# Processing Record 49 of Set 8 | ikalamavony
# Processing Record 50 of Set 8 | carauari
# Processing Record 1 of Set 9 | auki
# Processing Record 2 of Set 9 | leningradskiy
# Processing Record 3 of Set 9 | talca
# Processing Record 4 of Set 9 | labuhan
# Processing Record 5 of Set 9 | hualmay
# Processing Record 6 of Set 9 | kiruna
# Processing Record 7 of Set 9 | hobyo
# Processing Record 8 of Set 9 | padang
# Processing Record 9 of Set 9 | ucluelet
# Processing Record 10 of Set 9 | batsfjord
# Processing Record 11 of Set 9 | sao filipe
# Processing Record 12 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 13 of Set 9 | papara
# Processing Record 14 of Set 9 | nioro
# Processing Record 15 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 9 | coquimbo
# Processing Record 17 of Set 9 | kosa
# Processing Record 18 of Set 9 | doha
# Processing Record 19 of Set 9 | beihai
# Processing Record 20 of Set 9 | panalingaan
# Processing Record 21 of Set 9 | gat
# Processing Record 22 of Set 9 | pishin
# Processing Record 23 of Set 9 | kenai
# Processing Record 24 of Set 9 | klaksvik
# Processing Record 25 of Set 9 | catamarca
# Processing Record 26 of Set 9 | nikki
# Processing Record 27 of Set 9 | pimentel
# Processing Record 28 of Set 9 | jiaocheng
# Processing Record 29 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 9 | zatoka
# Processing Record 31 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 9 | creel
# Processing Record 33 of Set 9 | aripuana
# Processing Record 34 of Set 9 | urucui
# Processing Record 35 of Set 9 | kurchum
# Processing Record 36 of Set 9 | charters towers
# Processing Record 37 of Set 9 | hasaki
# Processing Record 38 of Set 9 | sai buri
# Processing Record 39 of Set 9 | cuaspud
# Processing Record 40 of Set 9 | dali
# Processing Record 41 of Set 9 | nonthaburi
# Processing Record 42 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 9 | ambunti
# Processing Record 44 of Set 9 | paamiut
# Processing Record 45 of Set 9 | nome
# Processing Record 46 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 9 | kadaya
# Processing Record 48 of Set 9 | bac lieu
# Processing Record 49 of Set 9 | kiunga
# Processing Record 50 of Set 9 | naze
# Processing Record 1 of Set 10 | eldorado
# Processing Record 2 of Set 10 | dalvik
# Processing Record 3 of Set 10 | gornopravdinsk
# Processing Record 4 of Set 10 | kyaikkami
# Processing Record 5 of Set 10 | moree
# Processing Record 6 of Set 10 | husavik
# Processing Record 7 of Set 10 | skibbereen
# Processing Record 8 of Set 10 | middelburg
# Processing Record 9 of Set 10 | miquelon
# Processing Record 10 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 10 | aulla
# Processing Record 12 of Set 10 | yook
# Processing Record 13 of Set 10 | koshurnikovo
# Processing Record 14 of Set 10 | balotra
# Processing Record 15 of Set 10 | tres lagoas
# Processing Record 16 of Set 10 | mosquera
# Processing Record 17 of Set 10 | kruisfontein
# Processing Record 18 of Set 10 | wenling
# Processing Record 19 of Set 10 | abu zabad
# Processing Record 20 of Set 10 | bitung
# Processing Record 21 of Set 10 | salinopolis
# Processing Record 22 of Set 10 | zeya
# Processing Record 23 of Set 10 | lexington
# Processing Record 24 of Set 10 | amahai
# Processing Record 25 of Set 10 | skagen
# Processing Record 26 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 10 | cadoneghe
# Processing Record 28 of Set 10 | marienburg
# Processing Record 29 of Set 10 | kulhudhuffushi
# Processing Record 30 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 10 | trincomalee
# Processing Record 32 of Set 10 | tommot
# Processing Record 33 of Set 10 | cayenne
# Processing Record 34 of Set 10 | progreso
# Processing Record 35 of Set 10 | bambous virieux
# Processing Record 36 of Set 10 | nantucket
# Processing Record 37 of Set 10 | saint anthony
# Processing Record 38 of Set 10 | sterling
# Processing Record 39 of Set 10 | praia
# Processing Record 40 of Set 10 | pangnirtung
# Processing Record 41 of Set 10 | sheopur
# Processing Record 42 of Set 10 | grants
# Processing Record 43 of Set 10 | bonfim
# Processing Record 44 of Set 10 | tifton
# Processing Record 45 of Set 10 | shimoda
# Processing Record 46 of Set 10 | mizpe ramon
# City not found. Skipping...
# Processing Record 47 of Set 10 | kandy
# Processing Record 48 of Set 10 | inirida
# Processing Record 49 of Set 10 | kushiro
# Processing Record 50 of Set 10 | egvekinot
# Processing Record 1 of Set 11 | khowst
# Processing Record 2 of Set 11 | bonthe
# Processing Record 3 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 4 of Set 11 | bajil
# Processing Record 5 of Set 11 | panuco
# Processing Record 6 of Set 11 | rudsar
# Processing Record 7 of Set 11 | mackay
# Processing Record 8 of Set 11 | sechura
# Processing Record 9 of Set 11 | vanavara
# Processing Record 10 of Set 11 | karratha
# Processing Record 11 of Set 11 | botro
# Processing Record 12 of Set 11 | hornepayne
# Processing Record 13 of Set 11 | fortuna
# Processing Record 14 of Set 11 | mukhen
# Processing Record 15 of Set 11 | kungurtug
# Processing Record 16 of Set 11 | zyryanka
# Processing Record 17 of Set 11 | kachug
# Processing Record 18 of Set 11 | umm kaddadah
# Processing Record 19 of Set 11 | lagoa
# Processing Record 20 of Set 11 | tynda
# Processing Record 21 of Set 11 | dingle
# Processing Record 22 of Set 11 | garowe
# Processing Record 23 of Set 11 | kushima
# Processing Record 24 of Set 11 | bukachacha
# Processing Record 25 of Set 11 | camacupa
# Processing Record 26 of Set 11 | boende
# Processing Record 27 of Set 11 | caohai
# Processing Record 28 of Set 11 | warrington
# Processing Record 29 of Set 11 | alice springs
# Processing Record 30 of Set 11 | buraydah
# Processing Record 31 of Set 11 | najran
# Processing Record 32 of Set 11 | bodaybo
# Processing Record 33 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 11 | yukamenskoye
# Processing Record 35 of Set 11 | mutsu
# Processing Record 36 of Set 11 | sturgis
# Processing Record 37 of Set 11 | iqaluit
# Processing Record 38 of Set 11 | russell
# Processing Record 39 of Set 11 | lakes entrance
# Processing Record 40 of Set 11 | caloundra
# Processing Record 41 of Set 11 | mardin
# Processing Record 42 of Set 11 | leova
# Processing Record 43 of Set 11 | half moon bay
# Processing Record 44 of Set 11 | urengoy
# Processing Record 45 of Set 11 | calatayud
# Processing Record 46 of Set 11 | asau
# Processing Record 47 of Set 11 | altar
# Processing Record 48 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 49 of Set 11 | teya
# Processing Record 50 of Set 11 | kunming
# Processing Record 1 of Set 12 | san quintin
# Processing Record 2 of Set 12 | tacuati
# Processing Record 3 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 4 of Set 12 | svetlyy
# Processing Record 5 of Set 12 | clovis
# Processing Record 6 of Set 12 | pedernales
# Processing Record 7 of Set 12 | monrovia
# Processing Record 8 of Set 12 | carutapera
# Processing Record 9 of Set 12 | mingaora
# Processing Record 10 of Set 12 | bluefields
# Processing Record 11 of Set 12 | tucuman
# Processing Record 12 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of Set 12 | talara
# Processing Record 14 of Set 12 | vakhtan
# Processing Record 15 of Set 12 | langfang
# Processing Record 16 of Set 12 | presidencia roque saenz pena
# Processing Record 17 of Set 12 | havoysund
# Processing Record 18 of Set 12 | mercedes
# Processing Record 19 of Set 12 | raudeberg
# Processing Record 20 of Set 12 | wexford
# Processing Record 21 of Set 12 | kharp
# Processing Record 22 of Set 12 | maragogi
# Processing Record 23 of Set 12 | sur
# Processing Record 24 of Set 12 | fallon
# Processing Record 25 of Set 12 | belogorsk
# Processing Record 26 of Set 12 | puerto escondido
# Processing Record 27 of Set 12 | dryden
# Processing Record 28 of Set 12 | santa barbara
# Processing Record 29 of Set 12 | kuusamo
# Processing Record 30 of Set 12 | dongsheng
# Processing Record 31 of Set 12 | duiwelskloof
# Processing Record 32 of Set 12 | shakhunya
# Processing Record 33 of Set 12 | curillo
# Processing Record 34 of Set 12 | kormilovka
# Processing Record 35 of Set 12 | gwalior
# Processing Record 36 of Set 12 | port augusta
# Processing Record 37 of Set 12 | puerto narino
# Processing Record 38 of Set 12 | namie
# Processing Record 39 of Set 12 | pevek
# Processing Record 40 of Set 12 | paidha
# Processing Record 41 of Set 12 | port lincoln
# Processing Record 42 of Set 12 | lerwick
# Processing Record 43 of Set 12 | merauke
# Processing Record 44 of Set 12 | meadow lake
# Processing Record 45 of Set 12 | namibe
# Processing Record 46 of Set 12 | cap malheureux
# Processing Record 47 of Set 12 | san isidro
# Processing Record 48 of Set 12 | kargil
# Processing Record 49 of Set 12 | dunedin
# Processing Record 50 of Set 12 | fort nelson
# Processing Record 1 of Set 13 | igurubi
# Processing Record 2 of Set 13 | impfondo
# Processing Record 3 of Set 13 | jequitinhonha
# Processing Record 4 of Set 13 | atar
# Processing Record 5 of Set 13 | nabire
# Processing Record 6 of Set 13 | lubango
# Processing Record 7 of Set 13 | po
# City not found. Skipping...
# Processing Record 8 of Set 13 | bilma
# Processing Record 9 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 13 | mandalgovi
# Processing Record 11 of Set 13 | oytal
# Processing Record 12 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 13 | banda aceh
# Processing Record 14 of Set 13 | mount isa
# Processing Record 15 of Set 13 | kiama
# Processing Record 16 of Set 13 | kampong thum
# Processing Record 17 of Set 13 | vila velha
# Processing Record 18 of Set 13 | platanos
# Processing Record 19 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 20 of Set 13 | raga
# Processing Record 21 of Set 13 | chulym
# Processing Record 22 of Set 13 | peterhead
# Processing Record 23 of Set 13 | vestmanna
# Processing Record 24 of Set 13 | qandala
# Processing Record 25 of Set 13 | tahoua
# Processing Record 26 of Set 13 | awbari
# Processing Record 27 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 28 of Set 13 | hambantota
# Processing Record 29 of Set 13 | lososina
# Processing Record 30 of Set 13 | cabedelo
# Processing Record 31 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 13 | miracema do tocantins
# Processing Record 33 of Set 13 | kahului
# Processing Record 34 of Set 13 | ixtapa
# Processing Record 35 of Set 13 | petatlan
# Processing Record 36 of Set 13 | tocache
# Processing Record 37 of Set 13 | nurota
# Processing Record 38 of Set 13 | manggar
# Processing Record 39 of Set 13 | palencia
# Processing Record 40 of Set 13 | kieta
# Processing Record 41 of Set 13 | willowmore
# Processing Record 42 of Set 13 | conceicao das alagoas
# Processing Record 43 of Set 13 | luwuk
# Processing Record 44 of Set 13 | toccoa
# Processing Record 45 of Set 13 | marzuq
# Processing Record 46 of Set 13 | gamba
# Processing Record 47 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 48 of Set 13 | cortez
# Processing Record 49 of Set 13 | contamana
# Processing Record 50 of Set 13 | shieli
# Processing Record 1 of Set 14 | sena madureira
# Processing Record 2 of Set 14 | belle glade
# Processing Record 3 of Set 14 | ituango
# Processing Record 4 of Set 14 | harper
# Processing Record 5 of Set 14 | wittmund
# Processing Record 6 of Set 14 | jardim
# Processing Record 7 of Set 14 | lemesos
# City not found. Skipping...
# Processing Record 8 of Set 14 | shelburne
# Processing Record 9 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 14 | zhezkazgan
# Processing Record 11 of Set 14 | pampierstad
# Processing Record 12 of Set 14 | ardakan
# Processing Record 13 of Set 14 | guerrero
# Processing Record 14 of Set 14 | otaru
# Processing Record 15 of Set 14 | sao jose da coroa grande
# Processing Record 16 of Set 14 | ahipara
# Processing Record 17 of Set 14 | conceicao do araguaia
# Processing Record 18 of Set 14 | darhan
# Processing Record 19 of Set 14 | high level
# Processing Record 20 of Set 14 | cookeville
# Processing Record 21 of Set 14 | balakhninskiy
# Processing Record 22 of Set 14 | polunochnoye
# Processing Record 23 of Set 14 | las matas de farfan
# Processing Record 24 of Set 14 | casambalangan
# Processing Record 25 of Set 14 | tias
# Processing Record 26 of Set 14 | huaihua
# Processing Record 27 of Set 14 | tocopilla
# Processing Record 28 of Set 14 | bozuyuk
# Processing Record 29 of Set 14 | novyy urgal
# Processing Record 30 of Set 14 | khani
# Processing Record 31 of Set 14 | caravelas
# Processing Record 32 of Set 14 | omagh
# Processing Record 33 of Set 14 | lompoc
# Processing Record 34 of Set 14 | ibanda
# Processing Record 35 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 36 of Set 14 | ribeira brava
# Processing Record 37 of Set 14 | north bend
# Processing Record 38 of Set 14 | yichang
# Processing Record 39 of Set 14 | chicama
# Processing Record 40 of Set 14 | broken hill
# Processing Record 41 of Set 14 | nortelandia
# Processing Record 42 of Set 14 | hukuntsi
# Processing Record 43 of Set 14 | wasilla
# Processing Record 44 of Set 14 | pestovo
# Processing Record 45 of Set 14 | asha
# Processing Record 46 of Set 14 | charlottesville
# Processing Record 47 of Set 14 | kilindoni
# Processing Record 48 of Set 14 | manacapuru
# Processing Record 49 of Set 14 | vilyuysk
# Processing Record 50 of Set 14 | weinan
# Processing Record 1 of Set 15 | santa maria
# Processing Record 2 of Set 15 | palaion ayionerion
# City not found. Skipping...
# Processing Record 3 of Set 15 | eydhafushi
# Processing Record 4 of Set 15 | sikeston
# Processing Record 5 of Set 15 | shiraz
# Processing Record 6 of Set 15 | adrar
# Processing Record 7 of Set 15 | goderich
# Processing Record 8 of Set 15 | muros
# Processing Record 9 of Set 15 | baguinge
# Processing Record 10 of Set 15 | bela
# Processing Record 11 of Set 15 | agadir
# Processing Record 12 of Set 15 | marystown
# Processing Record 13 of Set 15 | saint-louis
# Processing Record 14 of Set 15 | mount gambier
# Processing Record 15 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 16 of Set 15 | qaqortoq
# Processing Record 17 of Set 15 | mvangue
# Processing Record 18 of Set 15 | bow island
# Processing Record 19 of Set 15 | tebingtinggi
# Processing Record 20 of Set 15 | jerome
# Processing Record 21 of Set 15 | ballina
# Processing Record 22 of Set 15 | puerto colombia
# Processing Record 23 of Set 15 | bubaque
# Processing Record 24 of Set 15 | meulaboh
# Processing Record 25 of Set 15 | freeport
# Processing Record 26 of Set 15 | alashtar
# City not found. Skipping...
# Processing Record 27 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 28 of Set 15 | denpasar
# Processing Record 29 of Set 15 | matara
# Processing Record 30 of Set 15 | sangueya
# Processing Record 31 of Set 15 | lubbock
# Processing Record 32 of Set 15 | pozo colorado
# Processing Record 33 of Set 15 | qostanay
# Processing Record 34 of Set 15 | maniitsoq
# Processing Record 35 of Set 15 | celestun
# Processing Record 36 of Set 15 | ishinomaki
# Processing Record 37 of Set 15 | ndele
# Processing Record 38 of Set 15 | liepaja
# Processing Record 39 of Set 15 | el alto
# Processing Record 40 of Set 15 | charlestown
# Processing Record 41 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 15 | singkang
# Processing Record 43 of Set 15 | baghdad
# Processing Record 44 of Set 15 | dudinka
# Processing Record 45 of Set 15 | bria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 669     Celestun  20.87  -90.40     75.96        83          50       10.67
# 670   Ishinomaki  38.42  141.30     59.00        51          20        6.93
# 671        Ndele   8.41   20.65     81.70        67          55        5.10
# 672      Liepaja  56.54   21.04     42.80       100           0        1.12
# 673      El Alto  -4.27  -81.21     61.95        90          83       11.30
# 674  Charlestown -32.95  151.67     69.01        79          66        1.01
# 675     Singkang   2.10  102.80     87.80        70          40        5.82
# 676      Baghdad  33.34   44.40     82.40        23           0       11.41
# 677      Dudinka  69.41   86.18     14.00        85         100       33.55
# 678         Bria   6.54   21.99     74.19        87          90        2.59
#
#     Country                 Date
# 669      MX  2020-10-31 08:02:09
# 670      JP  2020-10-31 08:02:10
# 671      CF  2020-10-31 08:02:10
# 672      LV  2020-10-31 08:02:10
# 673      PE  2020-10-31 08:02:10
# 674      AU  2020-10-31 08:02:11
# 675      MY  2020-10-31 08:02:11
# 676      IQ  2020-10-31 08:02:11
# 677      RU  2020-10-31 08:02:12
# 678      CF  2020-10-31 08:02:12

# %%
# Rearrange the columns
columns = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[columns]
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0  Saint-Pierre      RE  2020-10-31 07:58:19 -21.34   55.48     75.20
# 1   Port Alfred      ZA  2020-10-31 07:58:19 -33.59   26.89     66.22
# 2      Yar-Sale      RU  2020-10-31 07:58:20  66.83   70.83     34.11
# 3  Port-Cartier      CA  2020-10-31 07:58:20  50.03  -66.87     26.60
# 4     Taoudenni      ML  2020-10-31 07:58:20  22.68   -3.98     76.12
# 5       Rikitea      PF  2020-10-31 07:58:20 -23.12 -134.97     75.31
# 6          Hilo      US  2020-10-31 07:58:20  19.73 -155.09     77.00
# 7         Tiksi      RU  2020-10-31 07:58:21  71.69  128.87      5.31
# 8    Bredasdorp      ZA  2020-10-31 07:58:21 -34.53   20.04     64.40
# 9    Nikolskoye      RU  2020-10-31 07:58:21  59.70   30.79     45.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        50          20       19.46
# 1        60          88        6.98
# 2        97         100       12.21
# 3        73           0        8.05
# 4        23          44       12.41
# 5        71           0        5.70
# 6        83          90        5.75
# 7        95          93        2.39
# 8        48           0        9.17
# 9        93          90        4.47

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
